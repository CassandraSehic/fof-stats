# %%
import pandas as pd
import itertools
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# Load the data from the .sav file
data = pd.read_spss('GEM2018NatData.sav')

# Specify the dependent variable
y = data['Frfail18']

# Specify the independent variables (if any)
# For example, if you have an independent variable called 'x', you can use:
# X = data[['x']]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Print the summary of the regression results
print(model.summary())
# Specify the independent variables
independent_variables = ['x1', 'x2', 'x3', 'x4']

# Initialize variables to store the best combination and its corresponding R-squared value
best_combination = None
best_r_squared = 0

# Iterate through all possible combinations of independent variables
for r in range(1, len(independent_variables) + 1):
    for combination in itertools.combinations(independent_variables, r):
        # Create a new X matrix with the current combination of variables
        X = data[list(combination)]
        X = sm.add_constant(X)
        
        # Fit the regression model
        model = sm.OLS(y, X).fit()
        
        # Get the R-squared value
        r_squared = model.rsquared
        
        # Check if the current combination has a higher R-squared value than the previous best
        if r_squared > best_r_squared:
            best_combination = combination
            best_r_squared = r_squared

# Print the best combination and its corresponding R-squared value
print("Best combination of variables:", best_combination)
print("R-squared value:", best_r_squared)
# Import the necessary libraries
# Specify the independent variables
independent_variables = ['x1', 'x2', 'x3', 'x4']

# Initialize the linear regression model
model = LinearRegression()
# Specify the independent variables
independent_variables = [col for col in data.columns if col != 'Frfail18']

# Initialize the RFE algorithm with the linear regression model
rfe = RFE(estimator=model)

# Fit the RFE algorithm to the data
rfe.fit(X, y)

# Get the selected features
selected_features = [independent_variables[i] for i in range(len(independent_variables)) if rfe.support_[i]]

# Print the selected features
print("Best combination of variables:", selected_features)
# Out:
# Running cells with 'Python 3.11.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/local/python/current/bin/python -m pip install ipykernel -U --user --force-reinstall'
